# %%
# !pip install langchain openai chromadb pypdf panel notebook
# Out:
# Requirement already satisfied: langchain in ./venv/lib/python3.9/site-packages (0.0.183)
# Requirement already satisfied: openai in ./venv/lib/python3.9/site-packages (0.27.7)
# Requirement already satisfied: chromadb in ./venv/lib/python3.9/site-packages (0.3.25)
# Requirement already satisfied: pypdf in ./venv/lib/python3.9/site-packages (3.9.0)
# Requirement already satisfied: panel in ./venv/lib/python3.9/site-packages (1.0.3)
# Requirement already satisfied: notebook in ./venv/lib/python3.9/site-packages (6.5.4)
# Requirement already satisfied: PyYAML>=5.4.1 in ./venv/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in ./venv/lib/python3.9/site-packages (from langchain) (0.5.7)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./venv/lib/python3.9/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in ./venv/lib/python3.9/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: pydantic<2,>=1 in ./venv/lib/python3.9/site-packages (from langchain) (1.10.8)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./venv/lib/python3.9/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./venv/lib/python3.9/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: numpy<2,>=1 in ./venv/lib/python3.9/site-packages (from langchain) (1.24.3)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./venv/lib/python3.9/site-packages (from langchain) (2.0.15)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in ./venv/lib/python3.9/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: tqdm in ./venv/lib/python3.9/site-packages (from openai) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in ./venv/lib/python3.9/site-packages (from chromadb) (7.3.1)
# Requirement already satisfied: pandas>=1.3 in ./venv/lib/python3.9/site-packages (from chromadb) (2.0.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./venv/lib/python3.9/site-packages (from chromadb) (1.15.0)
# Requirement already satisfied: tokenizers>=0.13.2 in ./venv/lib/python3.9/site-packages (from chromadb) (0.13.3)
# Requirement already satisfied: hnswlib>=0.7 in ./venv/lib/python3.9/site-packages (from chromadb) (0.7.0)
# Requirement already satisfied: clickhouse-connect>=0.5.7 in ./venv/lib/python3.9/site-packages (from chromadb) (0.5.25)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in ./venv/lib/python3.9/site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: duckdb>=0.7.1 in ./venv/lib/python3.9/site-packages (from chromadb) (0.8.0)
# Requirement already satisfied: posthog>=2.4.0 in ./venv/lib/python3.9/site-packages (from chromadb) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./venv/lib/python3.9/site-packages (from chromadb) (4.6.2)
# Requirement already satisfied: fastapi>=0.85.1 in ./venv/lib/python3.9/site-packages (from chromadb) (0.95.2)
# Requirement already satisfied: bokeh<3.2.0,>=3.1.1 in ./venv/lib/python3.9/site-packages (from panel) (3.1.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in ./venv/lib/python3.9/site-packages (from panel) (2.3.0)
# Requirement already satisfied: markdown-it-py in ./venv/lib/python3.9/site-packages (from panel) (2.2.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in ./venv/lib/python3.9/site-packages (from panel) (2023.5.0)
# Requirement already satisfied: linkify-it-py in ./venv/lib/python3.9/site-packages (from panel) (2.0.2)
# Requirement already satisfied: bleach in ./venv/lib/python3.9/site-packages (from panel) (6.0.0)
# Requirement already satisfied: mdit-py-plugins in ./venv/lib/python3.9/site-packages (from panel) (0.3.5)
# Requirement already satisfied: param>=1.12.0 in ./venv/lib/python3.9/site-packages (from panel) (1.13.0)
# Requirement already satisfied: markdown in ./venv/lib/python3.9/site-packages (from panel) (3.4.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in ./venv/lib/python3.9/site-packages (from notebook) (5.3.0)
# Requirement already satisfied: traitlets>=4.2.1 in ./venv/lib/python3.9/site-packages (from notebook) (5.9.0)
# Requirement already satisfied: nbformat in ./venv/lib/python3.9/site-packages (from notebook) (5.8.0)
# Requirement already satisfied: ipython-genutils in ./venv/lib/python3.9/site-packages (from notebook) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in ./venv/lib/python3.9/site-packages (from notebook) (1.8.2)
# Requirement already satisfied: jupyter-client>=5.3.4 in ./venv/lib/python3.9/site-packages (from notebook) (8.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in ./venv/lib/python3.9/site-packages (from notebook) (1.5.6)
# Requirement already satisfied: ipykernel in ./venv/lib/python3.9/site-packages (from notebook) (6.23.1)
# Requirement already satisfied: argon2-cffi in ./venv/lib/python3.9/site-packages (from notebook) (21.3.0)
# Requirement already satisfied: prometheus-client in ./venv/lib/python3.9/site-packages (from notebook) (0.17.0)
# Requirement already satisfied: nbconvert>=5 in ./venv/lib/python3.9/site-packages (from notebook) (7.4.0)
# Requirement already satisfied: nbclassic>=0.4.7 in ./venv/lib/python3.9/site-packages (from notebook) (1.0.0)
# Requirement already satisfied: tornado>=6.1 in ./venv/lib/python3.9/site-packages (from notebook) (6.3.2)
# Requirement already satisfied: terminado>=0.8.3 in ./venv/lib/python3.9/site-packages (from notebook) (0.17.1)
# Requirement already satisfied: pyzmq>=17 in ./venv/lib/python3.9/site-packages (from notebook) (25.1.0)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.9/site-packages (from notebook) (3.1.2)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: contourpy>=1 in ./venv/lib/python3.9/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (1.0.7)
# Requirement already satisfied: packaging>=16.8 in ./venv/lib/python3.9/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (23.1)
# Requirement already satisfied: pillow>=7.1.0 in ./venv/lib/python3.9/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (9.5.0)
# Requirement already satisfied: urllib3>=1.26 in ./venv/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2.0.2)
# Requirement already satisfied: zstandard in ./venv/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (0.21.0)
# Requirement already satisfied: pytz in ./venv/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2023.3)
# Requirement already satisfied: lz4 in ./venv/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (4.3.2)
# Requirement already satisfied: certifi in ./venv/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2023.5.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: typing-inspect>=0.4.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./venv/lib/python3.9/site-packages (from fastapi>=0.85.1->chromadb) (0.27.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.9/site-packages (from jinja2->notebook) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.9/site-packages (from jupyter-client>=5.3.4->notebook) (2.8.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in ./venv/lib/python3.9/site-packages (from jupyter-client>=5.3.4->notebook) (6.6.0)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.9/site-packages (from jupyter-core>=4.6.1->notebook) (3.5.1)
# Requirement already satisfied: jupyter-server>=1.8 in ./venv/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in ./venv/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook) (0.2.3)
# Requirement already satisfied: pygments>=2.4.1 in ./venv/lib/python3.9/site-packages (from nbconvert>=5->notebook) (2.15.1)
# Requirement already satisfied: defusedxml in ./venv/lib/python3.9/site-packages (from nbconvert>=5->notebook) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.9/site-packages (from nbconvert>=5->notebook) (4.12.2)
# Requirement already satisfied: jupyterlab-pygments in ./venv/lib/python3.9/site-packages (from nbconvert>=5->notebook) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./venv/lib/python3.9/site-packages (from nbconvert>=5->notebook) (0.8.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in ./venv/lib/python3.9/site-packages (from nbconvert>=5->notebook) (2.0.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./venv/lib/python3.9/site-packages (from nbconvert>=5->notebook) (1.5.0)
# Requirement already satisfied: tinycss2 in ./venv/lib/python3.9/site-packages (from nbconvert>=5->notebook) (1.2.1)
# Requirement already satisfied: jsonschema>=2.6 in ./venv/lib/python3.9/site-packages (from nbformat->notebook) (4.17.3)
# Requirement already satisfied: fastjsonschema in ./venv/lib/python3.9/site-packages (from nbformat->notebook) (2.17.1)
# Requirement already satisfied: sympy in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: flatbuffers in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: coloredlogs in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: protobuf in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (4.23.2)
# Requirement already satisfied: tzdata>=2022.1 in ./venv/lib/python3.9/site-packages (from pandas>=1.3->chromadb) (2023.3)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in ./venv/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./venv/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: ptyprocess in ./venv/lib/python3.9/site-packages (from terminado>=0.8.3->notebook) (0.7.0)
# Requirement already satisfied: h11>=0.8 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: click>=7.0 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.3)
# Requirement already satisfied: websockets>=10.4 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: httptools>=0.5.0 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.5.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.17.0)
# Requirement already satisfied: watchfiles>=0.13 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: python-dotenv>=0.13 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: argon2-cffi-bindings in ./venv/lib/python3.9/site-packages (from argon2-cffi->notebook) (21.2.0)
# Requirement already satisfied: webencodings in ./venv/lib/python3.9/site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./venv/lib/python3.9/site-packages (from ipykernel->notebook) (0.1.6)
# Requirement already satisfied: psutil in ./venv/lib/python3.9/site-packages (from ipykernel->notebook) (5.9.5)
# Requirement already satisfied: comm>=0.1.1 in ./venv/lib/python3.9/site-packages (from ipykernel->notebook) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./venv/lib/python3.9/site-packages (from ipykernel->notebook) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in ./venv/lib/python3.9/site-packages (from ipykernel->notebook) (8.13.2)
# Requirement already satisfied: appnope in ./venv/lib/python3.9/site-packages (from ipykernel->notebook) (0.1.3)
# Requirement already satisfied: uc-micro-py in ./venv/lib/python3.9/site-packages (from linkify-it-py->panel) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.9/site-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=5.3.4->notebook) (3.15.0)
# Requirement already satisfied: backcall in ./venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->notebook) (0.2.0)
# Requirement already satisfied: stack-data in ./venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->notebook) (0.6.2)
# Requirement already satisfied: decorator in ./venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->notebook) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->notebook) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->notebook) (4.8.0)
# Requirement already satisfied: pickleshare in ./venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->notebook) (0.7.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook) (0.19.3)
# Requirement already satisfied: jupyter-events>=0.6.0 in ./venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in ./venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.4.4)
# Requirement already satisfied: websocket-client in ./venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.5.2)
# Requirement already satisfied: anyio>=3.1.0 in ./venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (3.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: cffi>=1.0.1 in ./venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook) (2.4.1)
# Requirement already satisfied: humanfriendly>=9.1 in ./venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in ./venv/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.3.0)
# Requirement already satisfied: exceptiongroup in ./venv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.1.1)
# Requirement already satisfied: pycparser in ./venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./venv/lib/python3.9/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./venv/lib/python3.9/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./venv/lib/python3.9/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.1.1)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->notebook) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook) (1.2.0)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook) (2.2.1)
# Requirement already satisfied: fqdn in ./venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook) (1.5.1)
# Requirement already satisfied: uri-template in ./venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook) (1.2.0)
# Requirement already satisfied: isoduration in ./venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in ./venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook) (1.13)
# Requirement already satisfied: jsonpointer>1.13 in ./venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook) (2.3)
# Requirement already satisfied: arrow>=0.15.0 in ./venv/lib/python3.9/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook) (1.2.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !eval "$(pyenv init -)"
# !pyenv
# !python --version
import os
from langchain.chains import retrieval_qa
from langchain.llms import OpenAI
from langchain.document_loaders import TextLoader
from langchain.document_loaders import PyPDFLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
import panel as pn
# Out:
# Python 3.9.6
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 4
#       2 get_ipython().system('python --version')
#       3 import os
# ----> 4 from langchain.chains import retrieval_qa
#       5 from langchain.llms import OpenAI
#       6 from langchain.document_loaders import TextLoader
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/langchain/__init__.py:6
#       3 from importlib import metadata
#       4 from typing import Optional
# ----> 6 from langchain.agents import MRKLChain, ReActChain, SelfAskWithSearchChain
#       7 from langchain.cache import BaseCache
#       8 from langchain.chains import (
#       9     ConversationChain,
#      10     LLMBashChain,
#    (...)
#      18     VectorDBQAWithSourcesChain,
#      19 )
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/langchain/agents/__init__.py:2
#       1 """Interface for agents."""
# ----> 2 from langchain.agents.agent import (
#       3     Agent,
#       4     AgentExecutor,
#       5     AgentOutputParser,
#       6     BaseMultiActionAgent,
#       7     BaseSingleActionAgent,
#       8     LLMSingleActionAgent,
#       9 )
#      10 from langchain.agents.agent_toolkits import (
#      11     create_csv_agent,
#      12     create_json_agent,
#    (...)
#      21     create_vectorstore_router_agent,
#      22 )
#      23 from langchain.agents.agent_types import AgentType
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/langchain/agents/agent.py:16
#      13 from pydantic import BaseModel, root_validator
#      15 from langchain.agents.agent_types import AgentType
# ---> 16 from langchain.agents.tools import InvalidTool
#      17 from langchain.base_language import BaseLanguageModel
#      18 from langchain.callbacks.base import BaseCallbackManager
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/langchain/agents/tools.py:4
#       1 """Interface for tools."""
#       2 from typing import Optional
# ----> 4 from langchain.callbacks.manager import (
#       5     AsyncCallbackManagerForToolRun,
#       6     CallbackManagerForToolRun,
#       7 )
#       8 from langchain.tools.base import BaseTool, Tool, tool
#      11 class InvalidTool(BaseTool):
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/langchain/callbacks/__init__.py:6
#       4 from langchain.callbacks.clearml_callback import ClearMLCallbackHandler
#       5 from langchain.callbacks.comet_ml_callback import CometCallbackHandler
# ----> 6 from langchain.callbacks.manager import (
#       7     get_openai_callback,
#       8     tracing_enabled,
#       9 )
#      10 from langchain.callbacks.mlflow_callback import MlflowCallbackHandler
#      11 from langchain.callbacks.openai_info import OpenAICallbackHandler
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/langchain/callbacks/manager.py:24
#      22 from langchain.callbacks.openai_info import OpenAICallbackHandler
#      23 from langchain.callbacks.stdout import StdOutCallbackHandler
# ---> 24 from langchain.callbacks.tracers.langchain import LangChainTracer
#      25 from langchain.callbacks.tracers.langchain_v1 import LangChainTracerV1, TracerSessionV1
#      26 from langchain.callbacks.tracers.schemas import TracerSession
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/langchain/callbacks/tracers/__init__.py:3
#       1 """Tracers that record execution of LangChain runs."""
# ----> 3 from langchain.callbacks.tracers.langchain import LangChainTracer
#       4 from langchain.callbacks.tracers.langchain_v1 import LangChainTracerV1
#       5 from langchain.callbacks.tracers.stdout import ConsoleCallbackHandler
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/langchain/callbacks/tracers/langchain.py:10
#       7 from typing import Any, Dict, List, Optional
#       8 from uuid import UUID
# ---> 10 import requests
#      11 from tenacity import retry, stop_after_attempt, wait_fixed
#      13 from langchain.callbacks.tracers.base import BaseTracer
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/requests/__init__.py:43
#       6 """
#       7 Requests HTTP Library
#       8 ~~~~~~~~~~~~~~~~~~~~~
#    (...)
#      38 :license: Apache 2.0, see LICENSE for more details.
#      39 """
#      41 import warnings
# ---> 43 import urllib3
#      45 from .exceptions import RequestsDependencyWarning
#      47 try:
#
# File ~/Documents/GitHub/chat-icse/venv/lib/python3.9/site-packages/urllib3/__init__.py:38
#      32 else:
#      33     # fmt: off
#      34     if (
#      35         not ssl.OPENSSL_VERSION.startswith("OpenSSL ")
#      36         or ssl.OPENSSL_VERSION_INFO < (1, 1, 1)
#      37     ):  # Defensive:
# ---> 38         raise ImportError(
#      39             "urllib3 v2.0 only supports OpenSSL 1.1.1+, currently "
#      40             f"the 'ssl' module is compiled with {ssl.OPENSSL_VERSION}. "
#      41             "See: https://github.com/urllib3/urllib3/issues/2168"
#      42         )
#      43     # fmt: on
#      44
#      45 # === NOTE TO REPACKAGERS AND VENDORS ===
#      46 # Please delete this block, this logic is only
#      47 # for urllib3 being distributed via PyPI.
#      48 # See: https://github.com/urllib3/urllib3/issues/2680
#      49 try:
#
# ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with LibreSSL 2.8.3. See: https://github.com/urllib3/urllib3/issues/2168
